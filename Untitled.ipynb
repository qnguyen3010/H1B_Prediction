# %%
print(__doc__)

import numpy as np
import scipy as sp
import pandas as pd

from sklearn.preprocessing import Imputer

#read the csv into a dataframe
df = pd.read_csv('h1b_kaggle.csv')
# Out:
# Automatically created module for IPython interactive environment

# %%
df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
df.count()
# Out:
# Unnamed: 0            3002458
# CASE_STATUS           3002445
# EMPLOYER_NAME         3002399
# SOC_NAME              2984724
# JOB_TITLE             3002415
# FULL_TIME_POSITION    3002443
# PREVAILING_WAGE       3002373
# YEAR                  3002445
# WORKSITE              3002458
# lon                   2895216
# lat                   2895216
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  PREVAILING_WAGE          YEAR           lon           lat
# count  3.002458e+06     3.002373e+06  3.002445e+06  2.895216e+06  2.895216e+06
# mean   1.501230e+06     1.469984e+05  2.013855e+03 -9.213441e+01  3.816054e+01
# std    8.667351e+05     5.287609e+06  1.680612e+00  1.965591e+01  4.672835e+00
# min    1.000000e+00     0.000000e+00  2.011000e+03 -1.578583e+02  1.343719e+01
# 25%    7.506152e+05     5.437100e+04  2.012000e+03 -1.119261e+02  3.416536e+01
# 50%    1.501230e+06     6.502100e+04  2.014000e+03 -8.615862e+01  3.910312e+01
# 75%    2.251844e+06     8.143200e+04  2.015000e+03 -7.551381e+01  4.088374e+01
# max    3.002458e+06     6.997607e+09  2.016000e+03  1.457298e+02  6.483778e+01

# %%
df1 = df.dropna()
df1.count()
# Out:
# Unnamed: 0            2877765
# CASE_STATUS           2877765
# EMPLOYER_NAME         2877765
# SOC_NAME              2877765
# JOB_TITLE             2877765
# FULL_TIME_POSITION    2877765
# PREVAILING_WAGE       2877765
# YEAR                  2877765
# WORKSITE              2877765
# lon                   2877765
# lat                   2877765
# dtype: int64

# %%
df2 = df.drop(df.columns[[9, 10]], axis=1)

# %%
df2.count()
# Out:
# Unnamed: 0            3002458
# CASE_STATUS           3002445
# EMPLOYER_NAME         3002399
# SOC_NAME              2984724
# JOB_TITLE             3002415
# FULL_TIME_POSITION    3002443
# PREVAILING_WAGE       3002373
# YEAR                  3002445
# WORKSITE              3002458
# dtype: int64

# %%
len(df.SOC_NAME.unique())
# Out:
# 2133

# %%
len(df.JOB_TITLE.unique())
# Out:
# 287550

# %%
len(df.EMPLOYER_NAME.unique())
# Out:
# 236014

# %%
len(df.CASE_STATUS.unique())
df.CASE_STATUS.unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED', nan], dtype=object)

# %%
len(df.WORKSITE.unique())
# Out:
# 18622

# %%
df3 = df2.dropna(subset=['FULL_TIME_POSITION'])
df3.count()
# Out:
# Unnamed: 0            3002443
# CASE_STATUS           3002443
# EMPLOYER_NAME         3002398
# SOC_NAME              2984722
# JOB_TITLE             3002414
# FULL_TIME_POSITION    3002443
# PREVAILING_WAGE       3002373
# YEAR                  3002443
# WORKSITE              3002443
# dtype: int64

# %%
final_df = df.drop(df.columns[[9, 10]], axis=1).dropna()
final_df.count()
# Out:
# Unnamed: 0            2984609
# CASE_STATUS           2984609
# EMPLOYER_NAME         2984609
# SOC_NAME              2984609
# JOB_TITLE             2984609
# FULL_TIME_POSITION    2984609
# PREVAILING_WAGE       2984609
# YEAR                  2984609
# WORKSITE              2984609
# dtype: int64

# %%
final_df.describe()
# Out:
#          Unnamed: 0  PREVAILING_WAGE          YEAR
# count  2.984609e+06     2.984609e+06  2.984609e+06
# mean   1.496684e+06     1.469658e+05  2.013864e+03
# std    8.663691e+05     5.296147e+06  1.678808e+00
# min    1.000000e+00     0.000000e+00  2.011000e+03
# 25%    7.461800e+05     5.435000e+04  2.012000e+03
# 50%    1.494035e+06     6.500000e+04  2.014000e+03
# 75%    2.246552e+06     8.143200e+04  2.015000e+03
# max    3.002445e+06     6.997607e+09  2.016000e+03

# %%
final_df
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
final_df.rename(columns={'Unnamed: 0':'ID'}, inplace=True)
final_df.count()
# Out:
# ID                    2984609
# CASE_STATUS           2984609
# EMPLOYER_NAME         2984609
# SOC_NAME              2984609
# JOB_TITLE             2984609
# FULL_TIME_POSITION    2984609
# PREVAILING_WAGE       2984609
# YEAR                  2984609
# WORKSITE              2984609
# dtype: int64

# %%
final_df['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED                                             2600241
# CERTIFIED-WITHDRAWN                                    201479
# DENIED                                                  93761
# WITHDRAWN                                               89110
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    2
# INVALIDATED                                                 1
# Name: CASE_STATUS, dtype: int64

# %%
final_df1 = final_df[final_df.CASE_STATUS != "INVALIDATED"]
final_df1['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED                                             2600241
# CERTIFIED-WITHDRAWN                                    201479
# DENIED                                                  93761
# WITHDRAWN                                               89110
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    2
# Name: CASE_STATUS, dtype: int64

# %%
to_drop = ["INVALIDATED","REJECTED","PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED"]
final_df2 = final_df[~final_df['CASE_STATUS'].isin(to_drop)]
final_df2['CASE_STATUS'].value_counts()
# Out:
# CERTIFIED              2600241
# CERTIFIED-WITHDRAWN     201479
# DENIED                   93761
# WITHDRAWN                89110
# Name: CASE_STATUS, dtype: int64

# %%
final_df2
# Out:
#               ID          CASE_STATUS  \
# 0              1  CERTIFIED-WITHDRAWN
# 1              2  CERTIFIED-WITHDRAWN
# 2              3  CERTIFIED-WITHDRAWN
# 3              4  CERTIFIED-WITHDRAWN
# 4              5            WITHDRAWN
# 5              6  CERTIFIED-WITHDRAWN
# 6              7  CERTIFIED-WITHDRAWN
# 7              8  CERTIFIED-WITHDRAWN
# 8              9  CERTIFIED-WITHDRAWN
# 9             10            WITHDRAWN
# 10            11  CERTIFIED-WITHDRAWN
# 11            12  CERTIFIED-WITHDRAWN
# 12            13  CERTIFIED-WITHDRAWN
# 13            14  CERTIFIED-WITHDRAWN
# 14            15  CERTIFIED-WITHDRAWN
# 15            16  CERTIFIED-WITHDRAWN
# 16            17  CERTIFIED-WITHDRAWN
# 17            18  CERTIFIED-WITHDRAWN
# 18            19            CERTIFIED
# 19            20            CERTIFIED
# 20            21  CERTIFIED-WITHDRAWN
# 21            22  CERTIFIED-WITHDRAWN
# 22            23            CERTIFIED
# ...

# %%
final_df2.YEAR.unique()
len(final_df2.YEAR.unique())
# Out:
# 6

# %%
final_df2.YEAR.unique()
# Out:
# array([ 2016.,  2015.,  2014.,  2013.,  2012.,  2011.])
